# %%
import numpy as np
from astropy import units as u
from astropy import constants as c
import matplotlib.pyplot as plt
import firlim as fl
import importlib
importlib.reload(fl)
# Out:
# <module 'firlim' from '/Users/jaguirre/PyModules/STARsoft/Python/Simulation/firlim.py'>

# %%
z = np.linspace(0,6)
Mstar = 5e9*u.Msun
sSFR = fl.sSFR_MS(z,Mstar).to(np.power(u.Gyr,-1))
plt.semilogy(z,sSFR)
Mstar = 5e10*u.Msun
sSFR = fl.sSFR_MS(z,Mstar).to(np.power(u.Gyr,-1))
plt.semilogy(z,sSFR)
plt.xlabel('Redshift')
plt.ylabel('sSFR ()'+str(sSFR.unit)+')')
#print(sSFR.unit)
plt.ylim(.05,10)
plt.show()
